# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # xml code

# %%
# Import Module 
import os 
import pandas as pd
import xml.etree.ElementTree as ET

mrid_list = []
mdm_xml_file_name = []
k=1
# Folder Path 
path = r"C:\xml_format_file\MDM_XML_DATA"

# Change the directory 
os.chdir(path) 

# Read text File 


def read_text_file(file_path): 
	with open(file_path, 'r') as f: 
		print(f.read()) 


# iterate through all file 
for file in os.listdir(): 
	# Check whether file is in text format or not 
	if file.endswith(".xml"): 
		file_path = f"{path}\{file}"
		file_path = f"{path}\{file}"
		print(f"{k} : the  path is : {path}")
		print(f"{k} : the  file is : {file}")
		print(k)
		
		k=k+1
		tree = ET.parse(file_path)
		root = tree.getroot()

		# Define the namespace
		namespace = {'mtr': 'http://iec.ch/TC57/2011/MeterReadings#'}

		for meter_reading in root.findall('.//mtr:MeterReading', namespace):
			mrid = meter_reading.find('mtr:Meter/mtr:mRID', namespace).text

			mrid_list.append(mrid)
			mdm_xml_file_name.append(file)
			#file_name.append(file)
			#print(file_name)

data = {
    'Meter ID': mrid_list,
	'mdm_xml_file_name':mdm_xml_file_name
}

df_mdm = pd.DataFrame(data)

# %% [markdown]
# # some modification

# %%
# Import Module 
import os 
import pandas as pd
import xml.etree.ElementTree as ET

mrid_list = []
mdm_xml_file_name = []
k=1
# Folder Path 
path = r"C:\xml_format_file\Feb-bp"

# Change the directory 
os.chdir(path) 

# Read text File 


def read_text_file(file_path): 
	with open(file_path, 'r') as f: 
		print(f.read()) 


# iterate through all file 
for file in os.listdir(): 
	# Check whether file is in text format or not 
	if file.endswith(".xml"): 
		file_path = f"{path}\{file}"
		file_path = f"{path}\{file}"
		print(f"{k} : the  path is : {path}")
		print(f"{k} : the  file is : {file}")
		print(k)
		
		k=k+1
		tree = ET.parse(file_path)
		root = tree.getroot()

		# Define the namespace
		namespace = {'mtr': 'http://iec.ch/TC57/2011/MeterReadings#'}

		for meter_reading in root.findall('.//mtr:MeterReading', namespace):
			#mrid = meter_reading.find('mtr:Meter/mtr:mRID', namespace).text

			#mrid_list.append(mrid)
			mdm_xml_file_name.append(file)
			#file_name.append(file)
			#print(file_name)

data = {
    #'Meter ID': mrid_list,
	'mdm_xml_file_name':mdm_xml_file_name
}

df_mdm = pd.DataFrame(data)
# Out:
# 1 : the  path is : C:\xml_format_file\Feb-bp
# 1 : the  file is : Billing_determinant_000B1AFE-F277-433C-8015-D5421018D553.xml
# 1
# 2 : the  path is : C:\xml_format_file\Feb-bp
# 2 : the  file is : Billing_determinant_0014A0CA-2290-4722-8E03-C326BE6A8CBD.xml
# 2
# 3 : the  path is : C:\xml_format_file\Feb-bp
# 3 : the  file is : Billing_determinant_0038CD1E-A273-4B06-93AB-EA51974657F9.xml
# 3
# 4 : the  path is : C:\xml_format_file\Feb-bp
# 4 : the  file is : Billing_determinant_006EC4A5-140D-40C1-AAE3-A0085C23D686.xml
# 4
# 5 : the  path is : C:\xml_format_file\Feb-bp
# 5 : the  file is : Billing_determinant_0073A8D0-A264-4677-9446-52C2786DB0A0.xml
# 5
# 6 : the  path is : C:\xml_format_file\Feb-bp
# 6 : the  file is : Billing_determinant_0086F557-0953-44A2-8E60-276634C784B4.xml
# 6
# 7 : the  path is : C:\xml_format_file\Feb-bp
# 7 : the  file is : Billing_determinant_009D9D3E-A416-4065-B5DA-2A70FC6980FA.xml
# 7
# 8 : the  path is : C:\xml_format_file\Feb-bp
# 8 : the  file is : Billing_determinant_00A1E3A8-177E-4C14-843F-D7E4702E87FF.xml
# 8
# 9 : the  path is : C:\xml_format_file\Feb-bp
# 9 : the  file is : Billing_determinant_00A5CC14-D137-4106-BDA9-1A3BBA53E7CB.xml
# 9
# 10 : the  path is : C:\xml_format_file\Feb-bp
# 10 : the  file is : Billing_determinant_00BFE6A0-50B8-478D-9900-23EA78E3AD1C.xml
# 10
# 11 : the  path is : C:\xml_format_file\Feb-bp
# 11 : the  file is : Billing_determinant_00C8A5C0-9E82-49CA-A1E3-5826F56B6FEA.xml
# 11
# 12 : the  path is : C:\xml_format_file\Feb-bp
# 12 : the  file is : Billing_determinant_00E98542-2585-44CD-9A09-1D74FCE8FDA5.xml
# 12
# 13 : the  path is : C:\xml_format_file\Feb-bp
# 13 : the  file is : Billing_determinant_00EE91C6-C5A2-40E9-9050-C4A53556A045.xml
# 13
# 14 : the  path is : C:\xml_format_file\Feb-bp
# 14 : the  file is : Billing_determinant_00EEA6CF-EE0E-4B4C-9EA9-780EC1B61C62.xml
# 14
# 15 : the  path is : C:\xml_format_file\Feb-bp
# 15 : the  file is : Billing_determinant_012A9737-20A4-453A-91DC-F96EA3021F1C.xml
# 15
# 16 : the  path is : C:\xml_format_file\Feb-bp
# 16 : the  file is : Billing_determinant_01B37199-6B0F-46FE-9B17-E15F9A5606BB.xml
# 16
# 17 : the  path is : C:\xml_format_file\Feb-bp
# 17 : the  file is : Billing_determinant_01C8C858-00B2-4A7A-951F-24A73AD3CACB.xml
# 17
# 18 : the  path is : C:\xml_format_file\Feb-bp
# 18 : the  file is : Billing_determinant_01E94EB2-452F-491C-8685-E96198954FDB.xml
# 18
# 19 : the  path is : C:\xml_format_file\Feb-bp
# 19 : the  file is : Billing_determinant_01EFC21C-0452-4593-87AC-E7586D21FE1B.xml
# 19
# 20 : the  path is : C:\xml_format_file\Feb-bp
# 20 : the  file is : Billing_determinant_020A947E-BB8F-4294-AC98-587766AEB9DC.xml
# 20
# 21 : the  path is : C:\xml_format_file\Feb-bp
# 21 : the  file is : Billing_determinant_0239C991-6519-48F9-9020-BB2E6AFB10DB.xml
# 21
# 22 : the  path is : C:\xml_format_file\Feb-bp
# 22 : the  file is : Billing_determinant_023A30F9-0204-44F6-9BD0-675572F6E7B3.xml
# 22
# 23 : the  path is : C:\xml_format_file\Feb-bp
# 23 : the  file is : Billing_determinant_024F3EBA-D5FA-4DE9-97C5-DBAC1CDBA84E.xml
# 23
# 24 : the  path is : C:\xml_format_file\Feb-bp
# 24 : the  file is : Billing_determinant_026F2857-FEB0-42FD-998E-64C3CA763927.xml
# 24
# 25 : the  path is : C:\xml_format_file\Feb-bp
# 25 : the  file is : Billing_determinant_029C7C86-5025-434E-99EE-64DDC4FE96AE.xml
# 25
# 26 : the  path is : C:\xml_format_file\Feb-bp
# 26 : the  file is : Billing_determinant_02A6AB3A-F68E-4731-AA07-08883C7E0661.xml
# 26
# 27 : the  path is : C:\xml_format_file\Feb-bp
# 27 : the  file is : Billing_determinant_02D8B4D6-3B58-47CA-9E86-133A493976D3.xml
# 27
# 28 : the  path is : C:\xml_format_file\Feb-bp
# 28 : the  file is : Billing_determinant_0335EF59-C9B0-44C3-829D-40DAC01C9499.xml
# 28
# 29 : the  path is : C:\xml_format_file\Feb-bp
# 29 : the  file is : Billing_determinant_0353C468-5198-4672-AB95-F418699CEAC7.xml
# 29
# 30 : the  path is : C:\xml_format_file\Feb-bp
# 30 : the  file is : Billing_determinant_037CDE43-8EBC-43EF-9A2F-FF52CC97E266.xml
# 30
# 31 : the  path is : C:\xml_format_file\Feb-bp
# 31 : the  file is : Billing_determinant_03A0233B-FF58-4CAF-9BBE-AA8F252EA9B9.xml
# 31
# 32 : the  path is : C:\xml_format_file\Feb-bp
# 32 : the  file is : Billing_determinant_03D532EB-C232-4E51-BE44-DC3121389A3D.xml
# 32
# 33 : the  path is : C:\xml_format_file\Feb-bp
# 33 : the  file is : Billing_determinant_03EEDDBD-F5C6-4E39-BF8B-EF6533CA1B51.xml
# 33
# 34 : the  path is : C:\xml_format_file\Feb-bp
# 34 : the  file is : Billing_determinant_0404EF95-576E-4CDB-BA3B-5A8FBB799CCD.xml
# 34
# 35 : the  path is : C:\xml_format_file\Feb-bp
# 35 : the  file is : Billing_determinant_04112150-373A-4745-B069-F623282D7DBB.xml
# 35
# 36 : the  path is : C:\xml_format_file\Feb-bp
# 36 : the  file is : Billing_determinant_041DFBCB-B896-477A-994E-0C0F76B35F84.xml
# 36
# 37 : the  path is : C:\xml_format_file\Feb-bp
# 37 : the  file is : Billing_determinant_0445FC85-AEF6-49D3-BEFF-FC41C89308E2.xml
# 37
# 38 : the  path is : C:\xml_format_file\Feb-bp
# 38 : the  file is : Billing_determinant_04713E55-A138-4AC2-B779-CF8B72A0555C.xml
# 38
# 39 : the  path is : C:\xml_format_file\Feb-bp
# 39 : the  file is : Billing_determinant_048A0AC3-6F04-4484-B312-ECBCAC124ED7.xml
# 39
# 40 : the  path is : C:\xml_format_file\Feb-bp
# 40 : the  file is : Billing_determinant_04D04F74-ACA2-427E-B531-20CBE590EC38.xml
# 40
# 41 : the  path is : C:\xml_format_file\Feb-bp
# 41 : the  file is : Billing_determinant_0520610A-7F1D-4C9F-8858-98E27E49CAA9.xml
# 41
# 42 : the  path is : C:\xml_format_file\Feb-bp
# 42 : the  file is : Billing_determinant_05262B34-D7C3-4059-A231-ACFE31008877.xml
# 42
# 43 : the  path is : C:\xml_format_file\Feb-bp
# 43 : the  file is : Billing_determinant_052E8D4D-90B8-4D0C-94CA-3083B3544FBB.xml
# 43
# 44 : the  path is : C:\xml_format_file\Feb-bp
# 44 : the  file is : Billing_determinant_056E4805-7BD9-42B3-9999-5683895F9185.xml
# 44
# 45 : the  path is : C:\xml_format_file\Feb-bp
# 45 : the  file is : Billing_determinant_05C2937B-D9B9-4A34-AC54-92EA8C7F287C.xml
# 45
# 46 : the  path is : C:\xml_format_file\Feb-bp
# 46 : the  file is : Billing_determinant_05CC1ADA-1742-4A91-8221-6C188877B526.xml
# 46
# 47 : the  path is : C:\xml_format_file\Feb-bp
# 47 : the  file is : Billing_determinant_0602FEB3-1B9F-47E2-B290-2DF5E3284461.xml
# 47
# 48 : the  path is : C:\xml_format_file\Feb-bp
# 48 : the  file is : Billing_determinant_064D5307-7B41-4A05-9B88-6D0BF3EEF8C1.xml
# 48
# 49 : the  path is : C:\xml_format_file\Feb-bp
# 49 : the  file is : Billing_determinant_065C068B-A286-43C3-A7C7-C29AAB4AC153.xml
# 49
# 50 : the  path is : C:\xml_format_file\Feb-bp
# 50 : the  file is : Billing_determinant_06932C4D-3038-4A65-AEF3-0B469A7B9B05.xml
# 50
# 51 : the  path is : C:\xml_format_file\Feb-bp
# 51 : the  file is : Billing_determinant_069EA5B6-5D3C-4BF7-BD89-29FEE4D88674.xml
# 51
# 52 : the  path is : C:\xml_format_file\Feb-bp
# 52 : the  file is : Billing_determinant_06A6B520-0632-4ECF-AE72-0A373827CB69.xml
# 52
# 53 : the  path is : C:\xml_format_file\Feb-bp
# 53 : the  file is : Billing_determinant_06C368B3-59C9-4296-A30C-9CE4308DC23D.xml
# 53
# 54 : the  path is : C:\xml_format_file\Feb-bp
# 54 : the  file is : Billing_determinant_06E0BA01-89D9-4176-8754-F9C81803E219.xml
# 54
# 55 : the  path is : C:\xml_format_file\Feb-bp
# 55 : the  file is : Billing_determinant_06E7B8CC-12E0-474F-A0A6-5BC5E376902C.xml
# 55
# 56 : the  path is : C:\xml_format_file\Feb-bp
# 56 : the  file is : Billing_determinant_06EE74E7-2D18-4F8C-8612-937B682C3C16.xml
# 56
# 57 : the  path is : C:\xml_format_file\Feb-bp
# 57 : the  file is : Billing_determinant_070A18F9-89D0-42C9-B1BE-5BDF1C72EBC6.xml
# 57
# 58 : the  path is : C:\xml_format_file\Feb-bp
# 58 : the  file is : Billing_determinant_070EB4B4-32FB-47C5-B159-B776FFE774E0.xml
# 58
# 59 : the  path is : C:\xml_format_file\Feb-bp
# 59 : the  file is : Billing_determinant_07152EDE-EDF7-497B-A844-89A4E7F27CB6.xml
# 59
# 60 : the  path is : C:\xml_format_file\Feb-bp
# 60 : the  file is : Billing_determinant_073B5B6B-6063-4300-B1EB-B1109DECFAB2.xml
# 60
# 61 : the  path is : C:\xml_format_file\Feb-bp
# 61 : the  file is : Billing_determinant_073DD1D4-8A14-4193-855F-101D499487FC.xml
# 61
# 62 : the  path is : C:\xml_format_file\Feb-bp
# 62 : the  file is : Billing_determinant_076AA474-C686-4078-97DB-F9BD30CA9DF8.xml
# 62
# 63 : the  path is : C:\xml_format_file\Feb-bp
# 63 : the  file is : Billing_determinant_076BB565-2952-4F74-8397-AD5123BCE7AB.xml
# 63
# 64 : the  path is : C:\xml_format_file\Feb-bp
# 64 : the  file is : Billing_determinant_0789F5D2-EBE1-44C3-8681-A7C83ABCF6E3.xml
# 64
# 65 : the  path is : C:\xml_format_file\Feb-bp
# 65 : the  file is : Billing_determinant_0790E00C-CBB8-435C-8A15-7AB78FBDD2BB.xml
# 65
# 66 : the  path is : C:\xml_format_file\Feb-bp
# 66 : the  file is : Billing_determinant_0794C61F-5693-4BA4-B297-E3ED49BD961C.xml
# 66
# 67 : the  path is : C:\xml_format_file\Feb-bp
# 67 : the  file is : Billing_determinant_079DBBD3-9E97-4073-82A0-469752950E6D.xml
# 67
# 68 : the  path is : C:\xml_format_file\Feb-bp
# 68 : the  file is : Billing_determinant_0819B636-AEBD-4119-ACC8-0C32205A8D96.xml
# 68
# 69 : the  path is : C:\xml_format_file\Feb-bp
# 69 : the  file is : Billing_determinant_08C98168-9C9A-4DD0-A105-012754483133.xml
# 69
# 70 : the  path is : C:\xml_format_file\Feb-bp
# 70 : the  file is : Billing_determinant_08CA7ED0-B348-4158-B6D5-2B1BC363FBD0.xml
# 70
# 71 : the  path is : C:\xml_format_file\Feb-bp
# 71 : the  file is : Billing_determinant_08E01CD8-D8FD-48C2-9BF8-320632E8C51F.xml
# 71
# 72 : the  path is : C:\xml_format_file\Feb-bp
# 72 : the  file is : Billing_determinant_08E8A5D8-ACF5-4938-AFA0-8A77E5FD1C74.xml
# 72
# 73 : the  path is : C:\xml_format_file\Feb-bp
# 73 : the  file is : Billing_determinant_08EA21DE-F70C-4A64-B55F-106284CD74D1.xml
# 73
# 74 : the  path is : C:\xml_format_file\Feb-bp
# 74 : the  file is : Billing_determinant_0903DE63-5883-4338-AC0D-A12003D25DA6.xml
# 74
# 75 : the  path is : C:\xml_format_file\Feb-bp
# 75 : the  file is : Billing_determinant_090FFC34-6C56-4E7F-BC88-6DC9378591CC.xml
# 75
# 76 : the  path is : C:\xml_format_file\Feb-bp
# 76 : the  file is : Billing_determinant_0915F662-4964-428E-99E5-B0C89A29FA84.xml
# 76
# 77 : the  path is : C:\xml_format_file\Feb-bp
# 77 : the  file is : Billing_determinant_091AB051-50B7-4B3A-9324-42F91203806B.xml
# 77
# 78 : the  path is : C:\xml_format_file\Feb-bp
# 78 : the  file is : Billing_determinant_092BB048-50C1-4A81-B613-33FAAB46F9C5.xml
# 78
# 79 : the  path is : C:\xml_format_file\Feb-bp
# 79 : the  file is : Billing_determinant_096EC591-27EC-4B0E-96ED-0201FC1109BD.xml
# 79
# 80 : the  path is : C:\xml_format_file\Feb-bp
# 80 : the  file is : Billing_determinant_09B23E48-8433-4939-866D-9CF8D925EFA5.xml
# 80
# 81 : the  path is : C:\xml_format_file\Feb-bp
# 81 : the  file is : Billing_determinant_09ED1012-B745-4F46-A0E0-D1A94561BA5E.xml
# 81
# 82 : the  path is : C:\xml_format_file\Feb-bp
# 82 : the  file is : Billing_determinant_09F60FBC-F34E-46FF-8A7C-CE25C45E032F.xml
# 82
# 83 : the  path is : C:\xml_format_file\Feb-bp
# 83 : the  file is : Billing_determinant_09FE27EC-F911-4CEE-90C5-2FB912BA6E77.xml
# 83
# 84 : the  path is : C:\xml_format_file\Feb-bp
# 84 : the  file is : Billing_determinant_0A1AB610-5D25-4629-81F5-F49A9F43B4C2.xml
# 84
# 85 : the  path is : C:\xml_format_file\Feb-bp
# 85 : the  file is : Billing_determinant_0A21D7EF-BA94-425B-85C0-1C1AC37A25FC.xml
# 85
# 86 : the  path is : C:\xml_format_file\Feb-bp
# 86 : the  file is : Billing_determinant_0A266D2F-5986-461E-A70D-759DEC9AF367.xml
# 86
# 87 : the  path is : C:\xml_format_file\Feb-bp
# 87 : the  file is : Billing_determinant_0A2CCCFE-0923-44FE-9EE9-083D5371B29C.xml
# 87
# 88 : the  path is : C:\xml_format_file\Feb-bp
# 88 : the  file is : Billing_determinant_0A496266-E055-4ACE-9271-4F2F58F19C94.xml
# 88
# 89 : the  path is : C:\xml_format_file\Feb-bp
# 89 : the  file is : Billing_determinant_0A4BED17-C6B2-47AC-8FB3-C3F02AD0C1B3.xml
# 89
# 90 : the  path is : C:\xml_format_file\Feb-bp
# 90 : the  file is : Billing_determinant_0A6F4328-4403-4730-A647-FEF71F690AD0.xml
# 90
# 91 : the  path is : C:\xml_format_file\Feb-bp
# 91 : the  file is : Billing_determinant_0A7D5132-6342-4023-9527-CE640E8E5267.xml
# 91
# 92 : the  path is : C:\xml_format_file\Feb-bp
# 92 : the  file is : Billing_determinant_0AB37B9A-91C9-4017-A6D4-9B0664035BE9.xml
# 92
# 93 : the  path is : C:\xml_format_file\Feb-bp
# 93 : the  file is : Billing_determinant_0AC43711-2E68-44B5-AD2D-D7BEC88EFA23.xml
# 93
# 94 : the  path is : C:\xml_format_file\Feb-bp
# 94 : the  file is : Billing_determinant_0AF0E182-D4C7-4AAD-BD69-03DF3C3A20DD.xml
# 94
# 95 : the  path is : C:\xml_format_file\Feb-bp
# 95 : the  file is : Billing_determinant_0B0173FB-C838-472D-805C-28E0EFB1E7CF.xml
# 95
# 96 : the  path is : C:\xml_format_file\Feb-bp
# 96 : the  file is : Billing_determinant_0B2D1D2E-04F4-4F9D-9177-CBBDB74A364E.xml
# 96
# 97 : the  path is : C:\xml_format_file\Feb-bp
# 97 : the  file is : Billing_determinant_0B2D3394-85C0-4230-870E-55D44020A3FD.xml
# 97
# 98 : the  path is : C:\xml_format_file\Feb-bp
# 98 : the  file is : Billing_determinant_0BAAD81C-74EB-49BF-AF72-7BE02DD50357.xml
# 98
# 99 : the  path is : C:\xml_format_file\Feb-bp
# 99 : the  file is : Billing_determinant_0BC08821-9B6F-4730-B93F-F37C71D3AFAF.xml
# 99
# 100 : the  path is : C:\xml_format_file\Feb-bp
# 100 : the  file is : Billing_determinant_0BD8709C-A17C-4C8C-933C-884DD795F077.xml
# 100
# 101 : the  path is : C:\xml_format_file\Feb-bp
# 101 : the  file is : Billing_determinant_0BFE1816-C545-4F9B-982A-8C47C1EEAEB3.xml
# 101
# 102 : the  path is : C:\xml_format_file\Feb-bp
# 102 : the  file is : Billing_determinant_0C06EEE5-DDEB-4B96-AB7E-DCD79E2D0D7C.xml
# 102
# 103 : the  path is : C:\xml_format_file\Feb-bp
# 103 : the  file is : Billing_determinant_0C0DBF9C-C810-4C04-AAA3-9555F555B2C3.xml
# 103
# 104 : the  path is : C:\xml_format_file\Feb-bp
# 104 : the  file is : Billing_determinant_0C2882BA-1487-4484-99E3-E1F09F34FE9C.xml
# 104
# 105 : the  path is : C:\xml_format_file\Feb-bp
# 105 : the  file is : Billing_determinant_0C30EC9E-7A49-4762-83C4-80E296ED0417.xml
# 105
# 106 : the  path is : C:\xml_format_file\Feb-bp
# 106 : the  file is : Billing_determinant_0CD8E0D7-A519-46CD-8322-AADEC1B37321.xml
# 106
# 107 : the  path is : C:\xml_format_file\Feb-bp
# 107 : the  file is : Billing_determinant_0CE0A136-8919-4D27-8B8C-CA5E15AD782D.xml
# 107
# 108 : the  path is : C:\xml_format_file\Feb-bp
# 108 : the  file is : Billing_determinant_0CE6439B-F448-4BA6-BEFC-A452B4EAAC2D.xml
# 108
# 109 : the  path is : C:\xml_format_file\Feb-bp
# 109 : the  file is : Billing_determinant_0CF8679E-20AE-487F-9A5A-5A33D56791A8.xml
# 109
# 110 : the  path is : C:\xml_format_file\Feb-bp
# 110 : the  file is : Billing_determinant_0D401054-9258-49CA-AD19-B53E41457872.xml
# 110
# 111 : the  path is : C:\xml_format_file\Feb-bp
# 111 : the  file is : Billing_determinant_0D5751A5-F766-47E5-8340-85DFC5F49D03.xml
# 111
# 112 : the  path is : C:\xml_format_file\Feb-bp
# 112 : the  file is : Billing_determinant_0D9DB687-6565-4230-8A24-BFF711553E76.xml
# 112
# 113 : the  path is : C:\xml_format_file\Feb-bp
# 113 : the  file is : Billing_determinant_0DBE7BBC-0A7C-4718-B335-0C5BB140C125.xml
# 113
# 114 : the  path is : C:\xml_format_file\Feb-bp
# 114 : the  file is : Billing_determinant_0DCCF7BB-94D4-4207-9C61-F7A846E0E17C.xml
# 114
# 115 : the  path is : C:\xml_format_file\Feb-bp
# 115 : the  file is : Billing_determinant_0DD2978F-6F03-40D8-B364-3DD555B1C4D4.xml
# 115
# 116 : the  path is : C:\xml_format_file\Feb-bp
# 116 : the  file is : Billing_determinant_0E04DC65-BFA5-45DE-B27F-E38DBE024593.xml
# 116
# 117 : the  path is : C:\xml_format_file\Feb-bp
# 117 : the  file is : Billing_determinant_0E25B051-2B82-4993-AC93-8AED2566479A.xml
# 117
# 118 : the  path is : C:\xml_format_file\Feb-bp
# 118 : the  file is : Billing_determinant_0E339B77-28F2-4FC0-8D68-7230A41C0246.xml
# 118
# 119 : the  path is : C:\xml_format_file\Feb-bp
# 119 : the  file is : Billing_determinant_0E4F800C-D9CF-4074-8459-C9D517B8C1B1.xml
# 119
# 120 : the  path is : C:\xml_format_file\Feb-bp
# 120 : the  file is : Billing_determinant_0E92168B-FA3E-4E4E-8F42-FC47EC4E3878.xml
# 120
# 121 : the  path is : C:\xml_format_file\Feb-bp
# 121 : the  file is : Billing_determinant_0E9A0AD6-35FA-4E68-AABC-F4E8039BCB4D.xml
# 121
# 122 : the  path is : C:\xml_format_file\Feb-bp
# 122 : the  file is : Billing_determinant_0EA78A0C-6E9E-4386-8D02-C5440667676C.xml
# 122
# 123 : the  path is : C:\xml_format_file\Feb-bp
# 123 : the  file is : Billing_determinant_0ED7453D-80C8-4BF6-BECB-B3620D6081E2.xml
# 123
# 124 : the  path is : C:\xml_format_file\Feb-bp
# 124 : the  file is : Billing_determinant_0EE02D32-78A0-4935-892A-2F9C33DBC206.xml
# 124
# 125 : the  path is : C:\xml_format_file\Feb-bp
# 125 : the  file is : Billing_determinant_0EE7332A-191B-4855-B33B-D3305F5D9F3F.xml
# 125
# 126 : the  path is : C:\xml_format_file\Feb-bp
# 126 : the  file is : Billing_determinant_0EF1F626-A37C-4263-A673-1AB585F1AC45.xml
# 126
# 127 : the  path is : C:\xml_format_file\Feb-bp
# 127 : the  file is : Billing_determinant_0F3F914C-597F-4F3C-B9B9-B5B1BDEC8154.xml
# 127
# 128 : the  path is : C:\xml_format_file\Feb-bp
# 128 : the  file is : Billing_determinant_0F632111-0E78-463F-9EEA-8B89570CD79A.xml
# 128
# 129 : the  path is : C:\xml_format_file\Feb-bp
# 129 : the  file is : Billing_determinant_0F8DA60E-328B-435A-9484-ED1450F204C5.xml
# 129
# 130 : the  path is : C:\xml_format_file\Feb-bp
# 130 : the  file is : Billing_determinant_0FC88F80-1C42-4148-9BF5-AD04DF73AC01.xml
# 130
# 131 : the  path is : C:\xml_format_file\Feb-bp
# 131 : the  file is : Billing_determinant_0FCC5720-ADB0-4FA4-AFFD-31F1BE7CF053.xml
# 131
# 132 : the  path is : C:\xml_format_file\Feb-bp
# 132 : the  file is : Billing_determinant_0FD08049-120C-4623-AEA3-14740C6BD4F1.xml
# 132
# 133 : the  path is : C:\xml_format_file\Feb-bp
# 133 : the  file is : Billing_determinant_0FD3C996-1DBE-43EC-8B5F-8FC8E2AA45FB.xml
# 133
# 134 : the  path is : C:\xml_format_file\Feb-bp
# 134 : the  file is : Billing_determinant_0FE3BF1D-2A7D-4053-A4CD-BC78C6DC8FAB.xml
# 134
# 135 : the  path is : C:\xml_format_file\Feb-bp
# 135 : the  file is : Billing_determinant_0FE6F5F7-1107-44F4-A2B9-94F9CA2DBAE2.xml
# 135
# 136 : the  path is : C:\xml_format_file\Feb-bp
# 136 : the  file is : Billing_determinant_0FE8AF04-9619-461B-BEC7-BB04CAFE4418.xml
# 136
# 137 : the  path is : C:\xml_format_file\Feb-bp
# 137 : the  file is : Billing_determinant_0FEEEF7F-F2B0-4335-809F-E4A083257776.xml
# 137
# 138 : the  path is : C:\xml_format_file\Feb-bp
# 138 : the  file is : Billing_determinant_10C65705-93F4-4593-BF05-1BEE44B0C6E4.xml
# 138
# 139 : the  path is : C:\xml_format_file\Feb-bp
# 139 : the  file is : Billing_determinant_10D09B9F-716F-41E9-9F8C-C5CC8478697D.xml
# 139
# 140 : the  path is : C:\xml_format_file\Feb-bp
# 140 : the  file is : Billing_determinant_10D7BC66-5779-4A1A-9B4B-73B22DD014E7.xml
# 140
# 141 : the  path is : C:\xml_format_file\Feb-bp
# 141 : the  file is : Billing_determinant_1114E75A-CF5D-49B8-B0BB-4698C72383E1.xml
# 141
# 142 : the  path is : C:\xml_format_file\Feb-bp
# 142 : the  file is : Billing_determinant_1123D0FB-FA1A-42C2-9DAE-DA163E597911.xml
# 142
# 143 : the  path is : C:\xml_format_file\Feb-bp
# 143 : the  file is : Billing_determinant_11310A28-B794-4F33-A4F3-83FD3B1041A1.xml
# 143
# 144 : the  path is : C:\xml_format_file\Feb-bp
# 144 : the  file is : Billing_determinant_115F5F58-A21C-4287-8026-59E97FE63B0E.xml
# 144
# 145 : the  path is : C:\xml_format_file\Feb-bp
# 145 : the  file is : Billing_determinant_1183247D-230D-4377-8BA0-8270F7F357D8.xml
# 145
# 146 : the  path is : C:\xml_format_file\Feb-bp
# 146 : the  file is : Billing_determinant_11B05C36-90C7-4142-AB77-552EA77AA4E2.xml
# 146
# 147 : the  path is : C:\xml_format_file\Feb-bp
# 147 : the  file is : Billing_determinant_11B9D3CD-9197-4809-A19C-76FD127E4729.xml
# 147
# 148 : the  path is : C:\xml_format_file\Feb-bp
# 148 : the  file is : Billing_determinant_11BB8E60-BE9F-4FA2-94A5-8EA9CCDD939F.xml
# 148
# 149 : the  path is : C:\xml_format_file\Feb-bp
# 149 : the  file is : Billing_determinant_11BCDA7F-0609-482A-B452-AC6BF5A3D45A.xml
# 149
# 150 : the  path is : C:\xml_format_file\Feb-bp
# 150 : the  file is : Billing_determinant_11C9A163-30B0-4138-998F-F98A399F7FF5.xml
# 150
# 151 : the  path is : C:\xml_format_file\Feb-bp
# 151 : the  file is : Billing_determinant_11D43A67-0D03-43ED-95CB-3A2624F96891.xml
# 151
# 152 : the  path is : C:\xml_format_file\Feb-bp
# 152 : the  file is : Billing_determinant_11F3015B-3734-4453-993B-E3A06FFB27FD.xml
# 152
# 153 : the  path is : C:\xml_format_file\Feb-bp
# 153 : the  file is : Billing_determinant_121D63E3-9BCF-4B8C-AB5C-C94FB42E3206.xml
# 153
# 154 : the  path is : C:\xml_format_file\Feb-bp
# 154 : the  file is : Billing_determinant_12228AD4-D372-4102-9C9E-2DA7F1CF0F15.xml
# 154
# 155 : the  path is : C:\xml_format_file\Feb-bp
# 155 : the  file is : Billing_determinant_12371951-80F8-452C-A909-9B06879843DE.xml
# 155
# 156 : the  path is : C:\xml_format_file\Feb-bp
# 156 : the  file is : Billing_determinant_128588CA-6AA3-4B73-816E-244AB870AEBE.xml
# 156
# 157 : the  path is : C:\xml_format_file\Feb-bp
# 157 : the  file is : Billing_determinant_12943BE4-4242-4CCD-953A-9D3C35C61920.xml
# 157
# 158 : the  path is : C:\xml_format_file\Feb-bp
# 158 : the  file is : Billing_determinant_12C94EE8-347E-4565-BAE4-49B755DD52F7.xml
# 158
# 159 : the  path is : C:\xml_format_file\Feb-bp
# 159 : the  file is : Billing_determinant_130F12C8-1694-4E6E-B9C4-F36188AFDDD4.xml
# 159
# 160 : the  path is : C:\xml_format_file\Feb-bp
# 160 : the  file is : Billing_determinant_1322EAD5-E31D-4E8B-B7F1-97FB35C72E33.xml
# 160
# 161 : the  path is : C:\xml_format_file\Feb-bp
# 161 : the  file is : Billing_determinant_135D6535-8621-4431-9AE2-579A33D76B9C.xml
# 161
# 162 : the  path is : C:\xml_format_file\Feb-bp
# 162 : the  file is : Billing_determinant_136DDE99-BF15-47F6-A12C-3C69640351AE.xml
# 162
# 163 : the  path is : C:\xml_format_file\Feb-bp
# 163 : the  file is : Billing_determinant_136F231F-ACBA-4471-8AEA-DA049E32AFC0.xml
# 163
# 164 : the  path is : C:\xml_format_file\Feb-bp
# 164 : the  file is : Billing_determinant_13799066-70C4-49DB-9906-FFBB6E20F23F.xml
# 164
# 165 : the  path is : C:\xml_format_file\Feb-bp
# 165 : the  file is : Billing_determinant_13A3ED33-F8E4-4687-9287-EF348E31BDF2.xml
# 165
# 166 : the  path is : C:\xml_format_file\Feb-bp
# 166 : the  file is : Billing_determinant_13CBDF66-3CA0-4AD0-95BC-9EE791F9D56E.xml
# 166
# 167 : the  path is : C:\xml_format_file\Feb-bp
# 167 : the  file is : Billing_determinant_13ED5220-0A74-4313-9FF6-564222427CD3.xml
# 167
# 168 : the  path is : C:\xml_format_file\Feb-bp
# 168 : the  file is : Billing_determinant_144DA674-A448-4B40-925D-50170C458957.xml
# 168
# 169 : the  path is : C:\xml_format_file\Feb-bp
# 169 : the  file is : Billing_determinant_14797440-397F-479A-AEC3-8B97F7191924.xml
# 169
# 170 : the  path is : C:\xml_format_file\Feb-bp
# 170 : the  file is : Billing_determinant_147FD630-77DC-4A14-B4EF-9DEECD847AE2.xml
# 170
# 171 : the  path is : C:\xml_format_file\Feb-bp
# 171 : the  file is : Billing_determinant_14D61A0D-4FD9-4CF2-A8AF-E68C41FA0744.xml
# 171
# 172 : the  path is : C:\xml_format_file\Feb-bp
# 172 : the  file is : Billing_determinant_14E8C5F1-267E-4501-8C9A-FBAC22EFE713.xml
# 172
# 173 : the  path is : C:\xml_format_file\Feb-bp
# 173 : the  file is : Billing_determinant_14F45ED7-54AE-40B6-9CD2-38337D63E8BC.xml
# 173
# 174 : the  path is : C:\xml_format_file\Feb-bp
# 174 : the  file is : Billing_determinant_14FFAF36-096B-4D98-ADE3-ABE11FE1CAC8.xml
# 174
# 175 : the  path is : C:\xml_format_file\Feb-bp
# 175 : the  file is : Billing_determinant_154233DF-37CA-499B-A30B-C466FF3E079A.xml
# 175
# 176 : the  path is : C:\xml_format_file\Feb-bp
# 176 : the  file is : Billing_determinant_1558ACA1-7AEE-4FAC-BD80-519C7D3B7048.xml
# 176
# 177 : the  path is : C:\xml_format_file\Feb-bp
# 177 : the  file is : Billing_determinant_1565982D-8321-4DFB-8BCB-0E9018578444.xml
# 177
# 178 : the  path is : C:\xml_format_file\Feb-bp
# 178 : the  file is : Billing_determinant_1579A4A0-6593-4318-9C35-765D053AA64C.xml
# 178
# 179 : the  path is : C:\xml_format_file\Feb-bp
# 179 : the  file is : Billing_determinant_158F37CC-0ABC-44C3-91DC-0E477AFACD84.xml
# 179
# 180 : the  path is : C:\xml_format_file\Feb-bp
# 180 : the  file is : Billing_determinant_1594B61D-217E-44AB-81B6-BB0AC356444D.xml
# 180
# 181 : the  path is : C:\xml_format_file\Feb-bp
# 181 : the  file is : Billing_determinant_15A56670-438C-41AD-8905-B32037D5E140.xml
# 181
# 182 : the  path is : C:\xml_format_file\Feb-bp
# 182 : the  file is : Billing_determinant_15CE2E4D-6D04-493D-B4E7-A513BCBF2D51.xml
# 182
# 183 : the  path is : C:\xml_format_file\Feb-bp
# 183 : the  file is : Billing_determinant_15F0AC1D-FB1B-4E46-9C64-38765590BCDD.xml
# 183
# 184 : the  path is : C:\xml_format_file\Feb-bp
# 184 : the  file is : Billing_determinant_1606CCAF-45C6-4707-8860-2B2F79827532.xml
# 184
# 185 : the  path is : C:\xml_format_file\Feb-bp
# 185 : the  file is : Billing_determinant_16396E2D-DC9F-4366-AEDA-4304895297DD.xml
# 185
# 186 : the  path is : C:\xml_format_file\Feb-bp
# 186 : the  file is : Billing_determinant_166A76DA-88FD-443E-8E28-58EF9AA0AF43.xml
# 186
# 187 : the  path is : C:\xml_format_file\Feb-bp
# 187 : the  file is : Billing_determinant_16A1C843-30D7-4E4C-886A-63AA48A1CB09.xml
# 187
# 188 : the  path is : C:\xml_format_file\Feb-bp
# 188 : the  file is : Billing_determinant_1717D3AE-15A0-43CF-AADE-CED630D87017.xml
# 188
# 189 : the  path is : C:\xml_format_file\Feb-bp
# 189 : the  file is : Billing_determinant_171B6E76-C49E-45CA-8A16-DB3A9398086A.xml
# 189
# 190 : the  path is : C:\xml_format_file\Feb-bp
# 190 : the  file is : Billing_determinant_172D1E9A-44A7-47F2-A099-589A3EE35EA1.xml
# 190
# 191 : the  path is : C:\xml_format_file\Feb-bp
# 191 : the  file is : Billing_determinant_173E0D1F-5311-41C9-911B-0EE39FA62BFA.xml
# 191
# 192 : the  path is : C:\xml_format_file\Feb-bp
# 192 : the  file is : Billing_determinant_17487732-A8DB-4790-A974-34BAB1B5F730.xml
# 192
# 193 : the  path is : C:\xml_format_file\Feb-bp
# 193 : the  file is : Billing_determinant_1763B588-9441-4E18-A84E-B6DAC1E1D389.xml
# 193
# 194 : the  path is : C:\xml_format_file\Feb-bp
# 194 : the  file is : Billing_determinant_17654901-B2D4-4816-AF1A-344A98AC9F49.xml
# 194
# 195 : the  path is : C:\xml_format_file\Feb-bp
# 195 : the  file is : Billing_determinant_1769912E-3424-4D90-BC7D-913E2E8F50FC.xml
# 195
# 196 : the  path is : C:\xml_format_file\Feb-bp
# 196 : the  file is : Billing_determinant_176D42C3-A2BD-439D-83AB-1C52BECB305C.xml
# 196
# 197 : the  path is : C:\xml_format_file\Feb-bp
# 197 : the  file is : Billing_determinant_1781A2F1-2B5C-47B9-91AC-0C12996E3ABC.xml
# 197
# 198 : the  path is : C:\xml_format_file\Feb-bp
# 198 : the  file is : Billing_determinant_178216A4-E9E6-477E-958B-04B2CBEDE65B.xml
# 198
# 199 : the  path is : C:\xml_format_file\Feb-bp
# 199 : the  file is : Billing_determinant_1791D1EC-D450-4435-AE95-06F38CD52AC2.xml
# 199
# 200 : the  path is : C:\xml_format_file\Feb-bp
# 200 : the  file is : Billing_determinant_17AA2124-E0D5-408D-B187-ECBF49B2CFDF.xml
# 200
# 201 : the  path is : C:\xml_format_file\Feb-bp
# 201 : the  file is : Billing_determinant_17AD176F-48F3-4747-AC28-C8EFD8F64836.xml
# 201
# 202 : the  path is : C:\xml_format_file\Feb-bp
# 202 : the  file is : Billing_determinant_17AD34F9-FEA2-40B5-A5FB-09357DBE39D4.xml
# 202
# 203 : the  path is : C:\xml_format_file\Feb-bp
# 203 : the  file is : Billing_determinant_17B69040-F498-4455-83C3-ADD619EF79B6.xml
# 203
# 204 : the  path is : C:\xml_format_file\Feb-bp
# 204 : the  file is : Billing_determinant_17D8AE11-34D7-49C5-824F-A9168EAA03F8.xml
# 204
# 205 : the  path is : C:\xml_format_file\Feb-bp
# 205 : the  file is : Billing_determinant_17F29347-3C46-4792-9648-23B69E25A0A4.xml
# 205
# 206 : the  path is : C:\xml_format_file\Feb-bp
# 206 : the  file is : Billing_determinant_17FA88A6-7978-4A2F-B9C3-18AB2B717815.xml
# 206
# 207 : the  path is : C:\xml_format_file\Feb-bp
# 207 : the  file is : Billing_determinant_18151463-D019-487A-834A-360DF92497E6.xml
# 207
# 208 : the  path is : C:\xml_format_file\Feb-bp
# 208 : the  file is : Billing_determinant_184F8FE7-B24D-404A-8B8A-93869AAB27AA.xml
# 208
# 209 : the  path is : C:\xml_format_file\Feb-bp
# 209 : the  file is : Billing_determinant_188E4AC4-E468-4527-AEC7-4346A4CD88D0.xml
# 209
# 210 : the  path is : C:\xml_format_file\Feb-bp
# 210 : the  file is : Billing_determinant_18E53CF8-ED74-4A82-AA63-C3E3612DFBE5.xml
# 210
# 211 : the  path is : C:\xml_format_file\Feb-bp
# 211 : the  file is : Billing_determinant_18EFFAEF-72C6-40A2-B299-DC798C8907D0.xml
# 211
# 212 : the  path is : C:\xml_format_file\Feb-bp
# 212 : the  file is : Billing_determinant_18F453F6-FD29-48AE-8CF1-985A1DACADCE.xml
# 212
# 213 : the  path is : C:\xml_format_file\Feb-bp
# 213 : the  file is : Billing_determinant_18FA1B73-516D-4FB4-8FEA-B42A1E6C46A7.xml
# 213
# 214 : the  path is : C:\xml_format_file\Feb-bp
# 214 : the  file is : Billing_determinant_194D1276-7112-46EB-9100-053BDBF30D2E.xml
# 214
# 215 : the  path is : C:\xml_format_file\Feb-bp
# 215 : the  file is : Billing_determinant_1956BE9B-E381-4193-8687-4515FCF8FA11.xml
# 215
# 216 : the  path is : C:\xml_format_file\Feb-bp
# 216 : the  file is : Billing_determinant_19657ABC-8E3B-4A5A-883C-57AFEF2F077A.xml
# 216
# 217 : the  path is : C:\xml_format_file\Feb-bp
# 217 : the  file is : Billing_determinant_19AE5F24-94A6-4AD0-8656-D3FAF447379C.xml
# 217
# 218 : the  path is : C:\xml_format_file\Feb-bp
# 218 : the  file is : Billing_determinant_19DEB89A-C6E9-4A9F-8962-44D8BB88653E.xml
# 218
# 219 : the  path is : C:\xml_format_file\Feb-bp
# 219 : the  file is : Billing_determinant_19F3702C-3627-4700-AA76-B27C6BF0E25E.xml
# 219
# 220 : the  path is : C:\xml_format_file\Feb-bp
# 220 : the  file is : Billing_determinant_1A137D40-D854-4A41-BA06-FAB9635ACF0C.xml
# 220
# 221 : the  path is : C:\xml_format_file\Feb-bp
# 221 : the  file is : Billing_determinant_1A4CC0F4-B242-425B-A727-3FB1C587672B.xml
# 221
# 222 : the  path is : C:\xml_format_file\Feb-bp
# 222 : the  file is : Billing_determinant_1A648A7D-019A-4DEF-9E34-D969FA7098E0.xml
# 222
# 223 : the  path is : C:\xml_format_file\Feb-bp
# 223 : the  file is : Billing_determinant_1A8753E8-083A-4FD8-94DE-6C5304763967.xml
# 223
# 224 : the  path is : C:\xml_format_file\Feb-bp
# 224 : the  file is : Billing_determinant_1AB4BA67-69E3-42B3-AF7A-4F8C77104B0C.xml
# 224
# 225 : the  path is : C:\xml_format_file\Feb-bp
# 225 : the  file is : Billing_determinant_1AB56626-D32E-40B2-9200-48989667BC79.xml
# 225
# 226 : the  path is : C:\xml_format_file\Feb-bp
# 226 : the  file is : Billing_determinant_1ABF66CE-B383-4F01-B9F6-B12B543648D8.xml
# 226
# 227 : the  path is : C:\xml_format_file\Feb-bp
# 227 : the  file is : Billing_determinant_1AF29B9D-0DC1-41E3-BFF9-B183F3277178.xml
# 227
# 228 : the  path is : C:\xml_format_file\Feb-bp
# 228 : the  file is : Billing_determinant_1AF30BED-5E1A-42A5-8F47-C70F2FC1C19B.xml
# 228
# 229 : the  path is : C:\xml_format_file\Feb-bp
# 229 : the  file is : Billing_determinant_1AF57F93-C39C-4B47-86BB-68A8E1946A55.xml
# 229
# 230 : the  path is : C:\xml_format_file\Feb-bp
# 230 : the  file is : Billing_determinant_1AFA8C5C-6CB2-431F-8720-ABB92C695D81.xml
# 230
# 231 : the  path is : C:\xml_format_file\Feb-bp
# 231 : the  file is : Billing_determinant_1B01F934-8793-4B51-A4B0-5B621B77C2F7.xml
# 231
# 232 : the  path is : C:\xml_format_file\Feb-bp
# 232 : the  file is : Billing_determinant_1B1B8520-7700-4878-B5F8-1C7421F59632.xml
# 232
# 233 : the  path is : C:\xml_format_file\Feb-bp
# 233 : the  file is : Billing_determinant_1B1EECC0-8646-4B7B-ADBC-82389445DC6A.xml
# 233
# 234 : the  path is : C:\xml_format_file\Feb-bp
# 234 : the  file is : Billing_determinant_1B55C5AA-1411-40C1-BBF7-DFA0F237885F.xml
# 234
# 235 : the  path is : C:\xml_format_file\Feb-bp
# 235 : the  file is : Billing_determinant_1B5BE01E-8D29-4431-8BC4-AE7EAAA30DE7.xml
# 235
# 236 : the  path is : C:\xml_format_file\Feb-bp
# 236 : the  file is : Billing_determinant_1B7C7641-B547-4C5A-9ADF-41DFE88289C2.xml
# 236
# 237 : the  path is : C:\xml_format_file\Feb-bp
# 237 : the  file is : Billing_determinant_1B891061-8741-4FF3-B018-5A12A2188DC0.xml
# 237
# 238 : the  path is : C:\xml_format_file\Feb-bp
# 238 : the  file is : Billing_determinant_1BBC566C-4F23-4C8A-8813-BB2759757668.xml
# 238
# 239 : the  path is : C:\xml_format_file\Feb-bp
# 239 : the  file is : Billing_determinant_1BBEEB20-1918-4F79-BFE3-90D76E790460.xml
# 239
# 240 : the  path is : C:\xml_format_file\Feb-bp
# 240 : the  file is : Billing_determinant_1C061168-8878-4FD5-9E84-DE634CFD85A1.xml
# 240
# 241 : the  path is : C:\xml_format_file\Feb-bp
# 241 : the  file is : Billing_determinant_1C322350-6B9A-4C11-A23F-989273FC21AD.xml
# 241
# 242 : the  path is : C:\xml_format_file\Feb-bp
# 242 : the  file is : Billing_determinant_1C99CCDF-C9D4-4B43-A551-03DFCFCF732F.xml
# 242
# 243 : the  path is : C:\xml_format_file\Feb-bp
# 243 : the  file is : Billing_determinant_1CA708EC-4335-41B7-A665-1554772BE7BE.xml
# 243
# 244 : the  path is : C:\xml_format_file\Feb-bp
# 244 : the  file is : Billing_determinant_1CB868D8-0221-4356-A324-4C03B43EC58C.xml
# 244
# 245 : the  path is : C:\xml_format_file\Feb-bp
# 245 : the  file is : Billing_determinant_1CBA5EF2-1D4A-4B72-9800-A9ECCF97B037.xml
# 245
# 246 : the  path is : C:\xml_format_file\Feb-bp
# 246 : the  file is : Billing_determinant_1CE5A734-26C3-4F48-9272-BA626C487039.xml
# 246
# 247 : the  path is : C:\xml_format_file\Feb-bp
# 247 : the  file is : Billing_determinant_1CF70768-50AD-4125-A18C-80C717CB5A3B.xml
# 247
# 248 : the  path is : C:\xml_format_file\Feb-bp
# 248 : the  file is : Billing_determinant_1D2386F2-0960-45E5-A859-5FF9882D21CC.xml
# 248
# 249 : the  path is : C:\xml_format_file\Feb-bp
# 249 : the  file is : Billing_determinant_1D59E9B8-6C5A-464C-8076-67378DAD31D2.xml
# 249
# 250 : the  path is : C:\xml_format_file\Feb-bp
# 250 : the  file is : Billing_determinant_1D9D0EF0-F1C1-4106-BF31-2BEE338E07D8.xml
# 250
# 251 : the  path is : C:\xml_format_file\Feb-bp
# 251 : the  file is : Billing_determinant_1DB76456-DCD3-4FEF-8417-2CA285D13D35.xml
# 251
# 252 : the  path is : C:\xml_format_file\Feb-bp
# 252 : the  file is : Billing_determinant_1DBF5ABE-4DBC-425A-B551-16AB7E77651E.xml
# 252
# 253 : the  path is : C:\xml_format_file\Feb-bp
# 253 : the  file is : Billing_determinant_1E0E25AB-418A-41C5-BCB3-4F20671F1191.xml
# 253
# 254 : the  path is : C:\xml_format_file\Feb-bp
# 254 : the  file is : Billing_determinant_1E55C32F-1BB9-4F13-8949-58AB9C759795.xml
# 254
# 255 : the  path is : C:\xml_format_file\Feb-bp
# 255 : the  file is : Billing_determinant_1E585CE6-90C5-4622-ACA8-722F832D212A.xml
# 255
# 256 : the  path is : C:\xml_format_file\Feb-bp
# 256 : the  file is : Billing_determinant_1E670E14-A7C9-4A83-BACF-205578BC317E.xml
# 256
# 257 : the  path is : C:\xml_format_file\Feb-bp
# 257 : the  file is : Billing_determinant_1E9D9B1D-0613-42B3-96A9-6AF5B80D1074.xml
# 257
# 258 : the  path is : C:\xml_format_file\Feb-bp
# 258 : the  file is : Billing_determinant_1F4CAAA3-EBE3-438D-8C1A-8821A64CA3DC.xml
# 258
# 259 : the  path is : C:\xml_format_file\Feb-bp
# 259 : the  file is : Billing_determinant_1F51A081-E720-4904-BE20-E568844B7871.xml
# 259
# 260 : the  path is : C:\xml_format_file\Feb-bp
# 260 : the  file is : Billing_determinant_1F6ED1C9-3E95-4116-BD16-6895F9548808.xml
# 260
# 261 : the  path is : C:\xml_format_file\Feb-bp
# 261 : the  file is : Billing_determinant_1FBBC239-592A-4E80-BC49-E3B6BA48F646.xml
# 261
# 262 : the  path is : C:\xml_format_file\Feb-bp
# 262 : the  file is : Billing_determinant_1FF00733-BEE4-49A0-81E4-2D3FD5E1B16C.xml
# 262
# 263 : the  path is : C:\xml_format_file\Feb-bp
# 263 : the  file is : Billing_determinant_1FF693EF-51C5-4FC0-B4A9-AFEB25CE7303.xml
# 263
# 264 : the  path is : C:\xml_format_file\Feb-bp
# 264 : the  file is : Billing_determinant_2012281C-222E-447E-857C-914D3BA47D98.xml
# 264
# 265 : the  path is : C:\xml_format_file\Feb-bp
# 265 : the  file is : Billing_determinant_20364B53-FC1E-4446-BEFF-631CAB7246E6.xml
# 265
# 266 : the  path is : C:\xml_format_file\Feb-bp
# 266 : the  file is : Billing_determinant_2081FFDE-A56A-4E57-A760-4092FBBBD8F3.xml
# 266
# 267 : the  path is : C:\xml_format_file\Feb-bp
# 267 : the  file is : Billing_determinant_20BB58D2-44EA-421F-95BC-BD68E5B9524F.xml
# 267
# 268 : the  path is : C:\xml_format_file\Feb-bp
# 268 : the  file is : Billing_determinant_20C5433F-F857-4688-B002-C72A53488B5A.xml
# 268
# 269 : the  path is : C:\xml_format_file\Feb-bp
# 269 : the  file is : Billing_determinant_20CE3488-16D4-4FDF-89A4-8582C930CC31.xml
# 269
# 270 : the  path is : C:\xml_format_file\Feb-bp
# 270 : the  file is : Billing_determinant_20DFBBB0-1DD0-46F5-9A4B-9D92BF99ACBF.xml
# 270
# 271 : the  path is : C:\xml_format_file\Feb-bp
# 271 : the  file is : Billing_determinant_20F2721F-1A87-40D6-B5BA-91DE3435DF71.xml
# 271
# 272 : the  path is : C:\xml_format_file\Feb-bp
# 272 : the  file is : Billing_determinant_20F5E11E-A595-4D64-9AD2-A6A66861D83F.xml
# 272
# 273 : the  path is : C:\xml_format_file\Feb-bp
# 273 : the  file is : Billing_determinant_214F946C-7739-455D-A805-DAFF66072EEF.xml
# 273
# 274 : the  path is : C:\xml_format_file\Feb-bp
# 274 : the  file is : Billing_determinant_21AFEDAF-124E-447D-93D5-95F219D306F5.xml
# 274
# 275 : the  path is : C:\xml_format_file\Feb-bp
# 275 : the  file is : Billing_determinant_21B0AB68-8779-4333-9501-1DDC7EF11690.xml
# 275
# 276 : the  path is : C:\xml_format_file\Feb-bp
# 276 : the  file is : Billing_determinant_21C257C0-FF0F-4CFE-ADBC-7C5022F480CD.xml
# 276
# 277 : the  path is : C:\xml_format_file\Feb-bp
# 277 : the  file is : Billing_determinant_21EB9557-6C52-4B61-82C8-9AB9069B71A4.xml
# 277
# 278 : the  path is : C:\xml_format_file\Feb-bp
# 278 : the  file is : Billing_determinant_21F5E4F5-07A8-45A5-BA78-C58281F8EC38.xml
# 278
# 279 : the  path is : C:\xml_format_file\Feb-bp
# 279 : the  file is : Billing_determinant_21F93557-B147-4765-9D4A-E8841C59942F.xml
# 279
# 280 : the  path is : C:\xml_format_file\Feb-bp
# 280 : the  file is : Billing_determinant_223D9DE8-E2BA-46C2-9FBD-A7D4E1F4A723.xml
# 280
# 281 : the  path is : C:\xml_format_file\Feb-bp
# 281 : the  file is : Billing_determinant_2286E9CA-8453-4E3C-A0C6-0604E4D7BE62.xml
# 281
# 282 : the  path is : C:\xml_format_file\Feb-bp
# 282 : the  file is : Billing_determinant_229B5E2C-E8C0-4EC2-9A8A-96B2A1E2C1BB.xml
# 282
# 283 : the  path is : C:\xml_format_file\Feb-bp
# 283 : the  file is : Billing_determinant_22E5395B-CE15-42A3-B08C-3C9DD9F9C2DC.xml
# 283
# 284 : the  path is : C:\xml_format_file\Feb-bp
# 284 : the  file is : Billing_determinant_231F3EDD-F269-4D65-88EA-0A1DDCC88528.xml
# 284
# 285 : the  path is : C:\xml_format_file\Feb-bp
# 285 : the  file is : Billing_determinant_23328C6F-F6CF-443A-A4D6-EA92ED85DA4B.xml
# 285
# 286 : the  path is : C:\xml_format_file\Feb-bp
# 286 : the  file is : Billing_determinant_2336FDF5-4800-4DD1-A64B-A85A4DF72436.xml
# 286
# 287 : the  path is : C:\xml_format_file\Feb-bp
# 287 : the  file is : Billing_determinant_2370C589-48EF-4423-97D0-64079BC2DED4.xml
# 287
# 288 : the  path is : C:\xml_format_file\Feb-bp
# 288 : the  file is : Billing_determinant_23887C56-2F40-4313-BECB-449AA8D57D7A.xml
# 288
# 289 : the  path is : C:\xml_format_file\Feb-bp
# 289 : the  file is : Billing_determinant_240D4A42-E7C5-4FDF-B249-A0B7A477E02C.xml
# 289
# 290 : the  path is : C:\xml_format_file\Feb-bp
# 290 : the  file is : Billing_determinant_2417937C-A44B-498B-AA9F-DECC1CDF80F6.xml
# 290
# 291 : the  path is : C:\xml_format_file\Feb-bp
# 291 : the  file is : Billing_determinant_2423A3D2-D6BA-4B11-898A-D4A77330E63E.xml
# 291
# 292 : the  path is : C:\xml_format_file\Feb-bp
# 292 : the  file is : Billing_determinant_24493384-E40F-456B-8884-32404DAFA953.xml
# 292
# 293 : the  path is : C:\xml_format_file\Feb-bp
# 293 : the  file is : Billing_determinant_244EBFDA-F33D-4EFC-9ED5-116F34E3C9C1.xml
# 293
# 294 : the  path is : C:\xml_format_file\Feb-bp
# 294 : the  file is : Billing_determinant_2493250F-92CB-4DB0-A324-6107E3E5BE03.xml
# 294
# 295 : the  path is : C:\xml_format_file\Feb-bp
# 295 : the  file is : Billing_determinant_249E3E8F-8702-4B90-8D74-F9E4CC9C1860.xml
# 295
# 296 : the  path is : C:\xml_format_file\Feb-bp
# 296 : the  file is : Billing_determinant_24A7D167-FA0A-4837-81F7-51187396F22E.xml
# 296
# 297 : the  path is : C:\xml_format_file\Feb-bp
# 297 : the  file is : Billing_determinant_24A8AC31-0625-41F2-895C-F30CBB7C430F.xml
# 297
# 298 : the  path is : C:\xml_format_file\Feb-bp
# 298 : the  file is : Billing_determinant_24B61954-8656-434E-B72D-BD6C6B7C7EB5.xml
# 298
# 299 : the  path is : C:\xml_format_file\Feb-bp
# 299 : the  file is : Billing_determinant_24BBCFE1-7C3F-4F11-91CC-E32818608733.xml
# 299
# 300 : the  path is : C:\xml_format_file\Feb-bp
# 300 : the  file is : Billing_determinant_24CFD0DC-E5A4-4D0B-8546-EFD71E4AB5E0.xml
# 300
# 301 : the  path is : C:\xml_format_file\Feb-bp
# 301 : the  file is : Billing_determinant_24DB52B9-02E1-4B10-9853-B7DB34F08DA3.xml
# 301
# 302 : the  path is : C:\xml_format_file\Feb-bp
# 302 : the  file is : Billing_determinant_24F37783-710C-4F67-8025-988456A78578.xml
# 302
# 303 : the  path is : C:\xml_format_file\Feb-bp
# 303 : the  file is : Billing_determinant_2500ECCE-7B39-41B4-9A8F-4BAEED848144.xml
# 303
# 304 : the  path is : C:\xml_format_file\Feb-bp
# 304 : the  file is : Billing_determinant_25077ADC-1003-4794-A431-0F8FF79AC0EE.xml
# 304
# 305 : the  path is : C:\xml_format_file\Feb-bp
# 305 : the  file is : Billing_determinant_252B3C60-693E-48E6-8F7B-DCA272121353.xml
# 305
# 306 : the  path is : C:\xml_format_file\Feb-bp
# 306 : the  file is : Billing_determinant_253D1D25-EB2C-4A4D-8E8E-55BACCB44FB9.xml
# 306
# 307 : the  path is : C:\xml_format_file\Feb-bp
# 307 : the  file is : Billing_determinant_256B1A95-92D0-4518-8592-36C808C4B21A.xml
# 307
# 308 : the  path is : C:\xml_format_file\Feb-bp
# 308 : the  file is : Billing_determinant_257491B0-D210-4F01-AF4F-A26C628066C2.xml
# 308
# 309 : the  path is : C:\xml_format_file\Feb-bp
# 309 : the  file is : Billing_determinant_25A5DE9B-2E1B-407B-8E1E-3C2FFB89E505.xml
# 309
# 310 : the  path is : C:\xml_format_file\Feb-bp
# 310 : the  file is : Billing_determinant_25F0D88C-73E8-4315-8743-6552AE6C94BB.xml
# 310
# 311 : the  path is : C:\xml_format_file\Feb-bp
# 311 : the  file is : Billing_determinant_260DF24F-3C20-43C5-9218-973627E106E9.xml
# 311
# 312 : the  path is : C:\xml_format_file\Feb-bp
# 312 : the  file is : Billing_determinant_261E1279-DD44-4430-999F-651DB60DF3CE.xml
# 312
# 313 : the  path is : C:\xml_format_file\Feb-bp
# 313 : the  file is : Billing_determinant_2622DA16-A789-428E-89CE-A141A47FAEB1.xml
# 313
# 314 : the  path is : C:\xml_format_file\Feb-bp
# 314 : the  file is : Billing_determinant_2643DB08-8B57-4A96-88AE-06F3113CC57D.xml
# 314
# 315 : the  path is : C:\xml_format_file\Feb-bp
# 315 : the  file is : Billing_determinant_265A62EC-1409-4238-A743-19C83F575160.xml
# 315
# 316 : the  path is : C:\xml_format_file\Feb-bp
# 316 : the  file is : Billing_determinant_265C03F0-2576-4748-8773-3950F29C2F00.xml
# 316
# 317 : the  path is : C:\xml_format_file\Feb-bp
# 317 : the  file is : Billing_determinant_269432FD-F549-43C4-BF24-DA3D6AB9DB70.xml
# 317
# 318 : the  path is : C:\xml_format_file\Feb-bp
# 318 : the  file is : Billing_determinant_2699C28D-0A53-4635-9848-5DA64EB2F347.xml
# 318
# 319 : the  path is : C:\xml_format_file\Feb-bp
# 319 : the  file is : Billing_determinant_26B0530A-8FF9-4E6C-81F0-C934F47EF55B.xml
# 319
# 320 : the  path is : C:\xml_format_file\Feb-bp
# 320 : the  file is : Billing_determinant_26C8BC7F-7D23-4AA5-8FD6-77FD67C998B9.xml
# 320
# 321 : the  path is : C:\xml_format_file\Feb-bp
# 321 : the  file is : Billing_determinant_26DD8858-9544-4C3F-859B-61A77E19C47E.xml
# 321
# 322 : the  path is : C:\xml_format_file\Feb-bp
# 322 : the  file is : Billing_determinant_26E3413D-7D0A-4C9C-85E5-9D090B1EC3D1.xml
# 322
# 323 : the  path is : C:\xml_format_file\Feb-bp
# 323 : the  file is : Billing_determinant_26F1D95B-B8B1-4324-B2E4-81EFBA481EFF.xml
# 323
# 324 : the  path is : C:\xml_format_file\Feb-bp
# 324 : the  file is : Billing_determinant_2713A15A-4010-451D-80EB-D2ECE766948D.xml
# 324
# 325 : the  path is : C:\xml_format_file\Feb-bp
# 325 : the  file is : Billing_determinant_2724E48D-4253-4AFA-A061-38B1FCF632D4.xml
# 325
# 326 : the  path is : C:\xml_format_file\Feb-bp
# 326 : the  file is : Billing_determinant_2753DBC3-A0DC-418B-BA27-502656BF627D.xml
# 326
# 327 : the  path is : C:\xml_format_file\Feb-bp
# 327 : the  file is : Billing_determinant_27640B76-B051-46B7-8403-E6243C378E1F.xml
# 327
# 328 : the  path is : C:\xml_format_file\Feb-bp
# 328 : the  file is : Billing_determinant_276F1877-F7C7-45D7-B22B-7396E9B06933.xml
# 328
# 329 : the  path is : C:\xml_format_file\Feb-bp
# 329 : the  file is : Billing_determinant_27804940-8B3F-46E2-9430-ADAE075DB039.xml
# 329
# 330 : the  path is : C:\xml_format_file\Feb-bp
# 330 : the  file is : Billing_determinant_27BA93BD-3D7D-429B-9C79-54BF3BD2E666.xml
# 330
# 331 : the  path is : C:\xml_format_file\Feb-bp
# 331 : the  file is : Billing_determinant_2818EE9E-5E7C-4D89-AF83-056401B9D46B.xml
# 331
# 332 : the  path is : C:\xml_format_file\Feb-bp
# 332 : the  file is : Billing_determinant_281C0738-1941-4418-A9CB-741BA9626FF1.xml
# 332
# 333 : the  path is : C:\xml_format_file\Feb-bp
# 333 : the  file is : Billing_determinant_2833757B-3319-42AC-9E77-46BE74CA308B.xml
# 333
# 334 : the  path is : C:\xml_format_file\Feb-bp
# 334 : the  file is : Billing_determinant_2834A945-598F-4CBE-815E-38FB6F8B47C0.xml
# 334
# 335 : the  path is : C:\xml_format_file\Feb-bp
# 335 : the  file is : Billing_determinant_28559117-0FFC-4C62-857B-2C11A2938FF2.xml
# 335
# 336 : the  path is : C:\xml_format_file\Feb-bp
# 336 : the  file is : Billing_determinant_287D4FA8-87CE-400A-B0E9-4A2AE591D55C.xml
# 336
# 337 : the  path is : C:\xml_format_file\Feb-bp
# 337 : the  file is : Billing_determinant_28C25D5A-ED76-4D84-B466-7ED6BF7D71D1.xml
# 337
# 338 : the  path is : C:\xml_format_file\Feb-bp
# 338 : the  file is : Billing_determinant_28CDC71F-3E79-4CFC-869A-4603C7A2A38E.xml
# 338
# 339 : the  path is : C:\xml_format_file\Feb-bp
# 339 : the  file is : Billing_determinant_28DE3254-DFC3-4C60-96EF-7ED7537B7A33.xml
# 339
# 340 : the  path is : C:\xml_format_file\Feb-bp
# 340 : the  file is : Billing_determinant_28E4F300-E16D-474A-862C-54D79AFBAB9D.xml
# 340
# 341 : the  path is : C:\xml_format_file\Feb-bp
# 341 : the  file is : Billing_determinant_2931727C-9683-484E-96BF-1B066A5EF4F1.xml
# 341
# 342 : the  path is : C:\xml_format_file\Feb-bp
# 342 : the  file is : Billing_determinant_295774C1-7446-48CC-B1D8-EC142670F87B.xml
# 342
# 343 : the  path is : C:\xml_format_file\Feb-bp
# 343 : the  file is : Billing_determinant_295C84F1-95CF-419F-9B49-A96072886176.xml
# 343
# 344 : the  path is : C:\xml_format_file\Feb-bp
# 344 : the  file is : Billing_determinant_29621F1C-568C-4897-BD77-3096E46FC856.xml
# 344
# 345 : the  path is : C:\xml_format_file\Feb-bp
# 345 : the  file is : Billing_determinant_29D5025D-442A-40EB-8F57-316C67FF3096.xml
# 345
# 346 : the  path is : C:\xml_format_file\Feb-bp
# 346 : the  file is : Billing_determinant_29DFD6CC-A271-433F-A89D-5A3F162EBF70.xml
# 346
# 347 : the  path is : C:\xml_format_file\Feb-bp
# 347 : the  file is : Billing_determinant_29DFEA70-57CF-43EF-B18E-2C6DFC458EE9.xml
# 347
# 348 : the  path is : C:\xml_format_file\Feb-bp
# 348 : the  file is : Billing_determinant_29EADF03-BAB9-4353-B009-079F3ED3EFAD.xml
# 348
# 349 : the  path is : C:\xml_format_file\Feb-bp
# 349 : the  file is : Billing_determinant_29FE787B-86BA-4601-8469-B943773438B1.xml
# 349
# 350 : the  path is : C:\xml_format_file\Feb-bp
# 350 : the  file is : Billing_determinant_2A042F0A-FD51-47E5-8058-60103E1B8023.xml
# 350
# 351 : the  path is : C:\xml_format_file\Feb-bp
# 351 : the  file is : Billing_determinant_2A0CBCA9-F593-49CB-AB06-FE5527AAB49E.xml
# 351
# 352 : the  path is : C:\xml_format_file\Feb-bp
# 352 : the  file is : Billing_determinant_2A0FBC31-7E01-46FB-81D2-A8DD1A17B96C.xml
# 352
# 353 : the  path is : C:\xml_format_file\Feb-bp
# 353 : the  file is : Billing_determinant_2A15389F-BEF1-4C04-98AB-37A588099C96.xml
# 353
# 354 : the  path is : C:\xml_format_file\Feb-bp
# 354 : the  file is : Billing_determinant_2A211EF7-F807-4FDF-A714-92315472DB47.xml
# 354
# 355 : the  path is : C:\xml_format_file\Feb-bp
# 355 : the  file is : Billing_determinant_2A3BA812-93BE-4F96-AE6A-A085D72F360B.xml
# 355
# 356 : the  path is : C:\xml_format_file\Feb-bp
# 356 : the  file is : Billing_determinant_2A54D5A4-604B-4C7A-BFC0-E36812B176F2.xml
# 356
# 357 : the  path is : C:\xml_format_file\Feb-bp
# 357 : the  file is : Billing_determinant_2A992290-3364-4403-90ED-58A4BF198B9D.xml
# 357
# 358 : the  path is : C:\xml_format_file\Feb-bp
# 358 : the  file is : Billing_determinant_2AF8B4C3-5C2E-4E09-855A-CF1DE7DD8458.xml
# 358
# 359 : the  path is : C:\xml_format_file\Feb-bp
# 359 : the  file is : Billing_determinant_2B07419A-1959-41D1-8AA8-A877870ECF78.xml
# 359
# 360 : the  path is : C:\xml_format_file\Feb-bp
# 360 : the  file is : Billing_determinant_2B0BAA26-E5DA-4EF3-B9AC-D71E9B3B97D5.xml
# 360
# 361 : the  path is : C:\xml_format_file\Feb-bp
# 361 : the  file is : Billing_determinant_2B456ACD-5BA0-424A-9F8A-7776B050536C.xml
# 361
# 362 : the  path is : C:\xml_format_file\Feb-bp
# 362 : the  file is : Billing_determinant_2B886CAF-4E08-4ECE-A279-F1D8A077C342.xml
# 362
# 363 : the  path is : C:\xml_format_file\Feb-bp
# 363 : the  file is : Billing_determinant_2B899868-81E4-4ED5-B2B8-05221A1E1202.xml
# 363
# ...
# 1917 : the  file is : Billing_determinant_F10A9654-0037-424D-9171-7EAADFF5D0CD.xml
# 1917
# 1918 : the  path is : C:\xml_format_file\Feb-bp
# 1918 : the  file is : Billing_determinant_F147B1F7-F2C0-4D8F-B0A6-AD80D2E2D6EA.xml
# 1918
# 1919 : the  path is : C:\xml_format_file\Feb-bp
# 1919 : the  file is : Billing_determinant_F168CF22-6020-4F2D-8211-8811E33E9CBB.xml
# 1919
# 1920 : the  path is : C:\xml_format_file\Feb-bp
# 1920 : the  file is : Billing_determinant_F16CFFDB-A755-4632-9EDA-4C832FB88DDF.xml
# 1920
# 1921 : the  path is : C:\xml_format_file\Feb-bp
# 1921 : the  file is : Billing_determinant_F17117CB-E457-4402-9918-2550A1DD9268.xml
# 1921
# 1922 : the  path is : C:\xml_format_file\Feb-bp
# 1922 : the  file is : Billing_determinant_F1AF3BBB-EA01-4F9D-A252-14558E6CE773.xml
# 1922
# 1923 : the  path is : C:\xml_format_file\Feb-bp
# 1923 : the  file is : Billing_determinant_F1BD3CBD-0D32-4207-AF49-A1FC72A7F0A0.xml
# 1923
# 1924 : the  path is : C:\xml_format_file\Feb-bp
# 1924 : the  file is : Billing_determinant_F1C3D39B-4271-4FEC-81E5-8CB5696ABBE2.xml
# 1924
# 1925 : the  path is : C:\xml_format_file\Feb-bp
# 1925 : the  file is : Billing_determinant_F1D53E88-5F7E-4FAA-ACAE-53D21A610284.xml
# 1925
# 1926 : the  path is : C:\xml_format_file\Feb-bp
# 1926 : the  file is : Billing_determinant_F1D56324-83EE-4E4C-BAE8-22A34D0D9F7B.xml
# 1926
# 1927 : the  path is : C:\xml_format_file\Feb-bp
# 1927 : the  file is : Billing_determinant_F1E51B41-B35C-4C58-9165-3D546A961FE7.xml
# 1927
# 1928 : the  path is : C:\xml_format_file\Feb-bp
# 1928 : the  file is : Billing_determinant_F202289C-4A5F-4660-9387-4420E6CFCF88.xml
# 1928
# 1929 : the  path is : C:\xml_format_file\Feb-bp
# 1929 : the  file is : Billing_determinant_F21BECB2-4684-4F76-A655-1F2420C5765E.xml
# 1929
# 1930 : the  path is : C:\xml_format_file\Feb-bp
# 1930 : the  file is : Billing_determinant_F258CA73-270A-4EDC-BDA8-428E25E865F8.xml
# 1930
# 1931 : the  path is : C:\xml_format_file\Feb-bp
# 1931 : the  file is : Billing_determinant_F2661755-89D6-4325-9FA7-266F8CE9AE88.xml
# 1931
# 1932 : the  path is : C:\xml_format_file\Feb-bp
# 1932 : the  file is : Billing_determinant_F26D3430-83BC-4C1C-8A40-576B09A262F3.xml
# 1932
# 1933 : the  path is : C:\xml_format_file\Feb-bp
# 1933 : the  file is : Billing_determinant_F27BFCB1-4853-45F7-913C-E266C2848018.xml
# 1933
# 1934 : the  path is : C:\xml_format_file\Feb-bp
# 1934 : the  file is : Billing_determinant_F2BA0971-2C0E-4CD6-BF38-19B4BC4E1AA8.xml
# 1934
# 1935 : the  path is : C:\xml_format_file\Feb-bp
# 1935 : the  file is : Billing_determinant_F2E3C4B5-A885-4BA0-9544-7FB6CA7A619E.xml
# 1935
# 1936 : the  path is : C:\xml_format_file\Feb-bp
# 1936 : the  file is : Billing_determinant_F2E87379-6CD1-43B2-B944-274480DD283B.xml
# 1936
# 1937 : the  path is : C:\xml_format_file\Feb-bp
# 1937 : the  file is : Billing_determinant_F31377A8-5578-46C3-B3CA-B30EC6CCBD5C.xml
# 1937
# 1938 : the  path is : C:\xml_format_file\Feb-bp
# 1938 : the  file is : Billing_determinant_F31F996F-B58D-4A25-A6DB-191E6D4B6153.xml
# 1938
# 1939 : the  path is : C:\xml_format_file\Feb-bp
# 1939 : the  file is : Billing_determinant_F32DD7A5-95DA-4E3F-BD4C-12EA72B07E0A.xml
# 1939
# 1940 : the  path is : C:\xml_format_file\Feb-bp
# 1940 : the  file is : Billing_determinant_F32F2D41-ECE1-4E95-B070-EE674ACD3B95.xml
# 1940
# 1941 : the  path is : C:\xml_format_file\Feb-bp
# 1941 : the  file is : Billing_determinant_F3678E18-0ECA-4A64-B0B6-8F523B5A1255.xml
# 1941
# 1942 : the  path is : C:\xml_format_file\Feb-bp
# 1942 : the  file is : Billing_determinant_F38FE1C1-AD5B-4DB8-970E-4A63598A39D8.xml
# 1942
# 1943 : the  path is : C:\xml_format_file\Feb-bp
# 1943 : the  file is : Billing_determinant_F3DD38E1-F7CD-4D09-AD1C-710058941951.xml
# 1943
# 1944 : the  path is : C:\xml_format_file\Feb-bp
# 1944 : the  file is : Billing_determinant_F456E26C-A22E-4DAD-9923-B1D3EBC443B0.xml
# 1944
# 1945 : the  path is : C:\xml_format_file\Feb-bp
# 1945 : the  file is : Billing_determinant_F468EA32-5018-4F16-9BD5-F9BE5338F6F4.xml
# 1945
# 1946 : the  path is : C:\xml_format_file\Feb-bp
# 1946 : the  file is : Billing_determinant_F49F3E91-115F-452C-AF0E-F59C4C1BED00.xml
# 1946
# 1947 : the  path is : C:\xml_format_file\Feb-bp
# 1947 : the  file is : Billing_determinant_F4C52DA3-234C-4579-A626-D8F95214E745.xml
# 1947
# 1948 : the  path is : C:\xml_format_file\Feb-bp
# 1948 : the  file is : Billing_determinant_F4C731D3-365F-4EC9-AB73-51112F3A9CFC.xml
# 1948
# 1949 : the  path is : C:\xml_format_file\Feb-bp
# 1949 : the  file is : Billing_determinant_F4C9DAEC-2B04-4C79-A589-FAC0C1265EF4.xml
# 1949
# 1950 : the  path is : C:\xml_format_file\Feb-bp
# 1950 : the  file is : Billing_determinant_F4D61A00-1588-4231-AD97-04376EBC7654.xml
# 1950
# 1951 : the  path is : C:\xml_format_file\Feb-bp
# 1951 : the  file is : Billing_determinant_F4EE5BAA-E54A-45BF-AC23-A5F433EBFF4F.xml
# 1951
# 1952 : the  path is : C:\xml_format_file\Feb-bp
# 1952 : the  file is : Billing_determinant_F529349B-FDC0-4CB9-BBC0-5A4548240185.xml
# 1952
# 1953 : the  path is : C:\xml_format_file\Feb-bp
# 1953 : the  file is : Billing_determinant_F577DA6A-87E1-4A66-9086-B972ED8D3088.xml
# 1953
# 1954 : the  path is : C:\xml_format_file\Feb-bp
# 1954 : the  file is : Billing_determinant_F5A8F67E-A585-4B49-A602-0588E58CBB7C.xml
# 1954
# 1955 : the  path is : C:\xml_format_file\Feb-bp
# 1955 : the  file is : Billing_determinant_F5C10CD7-EF99-4C2D-945D-3A40F079C1BE.xml
# 1955
# 1956 : the  path is : C:\xml_format_file\Feb-bp
# 1956 : the  file is : Billing_determinant_F61F8DE2-57C3-4F84-9135-041D33CFD98B.xml
# 1956
# 1957 : the  path is : C:\xml_format_file\Feb-bp
# 1957 : the  file is : Billing_determinant_F6272F32-F6FB-4386-9544-69E63E1EA80B.xml
# 1957
# 1958 : the  path is : C:\xml_format_file\Feb-bp
# 1958 : the  file is : Billing_determinant_F62C7C91-2D8F-42E6-8C3D-292A39BEB31C.xml
# 1958
# 1959 : the  path is : C:\xml_format_file\Feb-bp
# 1959 : the  file is : Billing_determinant_F6399417-BF68-4551-95CE-603EEEAE0E1E.xml
# 1959
# 1960 : the  path is : C:\xml_format_file\Feb-bp
# 1960 : the  file is : Billing_determinant_F64C1D93-CEE8-419F-BD70-3307CE0685BA.xml
# 1960
# 1961 : the  path is : C:\xml_format_file\Feb-bp
# 1961 : the  file is : Billing_determinant_F6A136D9-5E47-4B0E-B627-D588D7515485.xml
# 1961
# 1962 : the  path is : C:\xml_format_file\Feb-bp
# 1962 : the  file is : Billing_determinant_F6D2D6A7-D5F2-40A2-A266-EC7E817EFADB.xml
# 1962
# 1963 : the  path is : C:\xml_format_file\Feb-bp
# 1963 : the  file is : Billing_determinant_F6E4336B-C355-48EF-87CA-75317543BAB6.xml
# 1963
# 1964 : the  path is : C:\xml_format_file\Feb-bp
# 1964 : the  file is : Billing_determinant_F6E9F501-CC7A-4261-BE0D-B6B3CC43A530.xml
# 1964
# 1965 : the  path is : C:\xml_format_file\Feb-bp
# 1965 : the  file is : Billing_determinant_F6EBF2E4-82EB-4436-A049-3B02610606B8.xml
# 1965
# 1966 : the  path is : C:\xml_format_file\Feb-bp
# 1966 : the  file is : Billing_determinant_F71784AA-4F92-434E-AFCE-9E87D8302146.xml
# 1966
# 1967 : the  path is : C:\xml_format_file\Feb-bp
# 1967 : the  file is : Billing_determinant_F723F70F-BE7D-4594-9400-7D9F5BD0FD2C.xml
# 1967
# 1968 : the  path is : C:\xml_format_file\Feb-bp
# 1968 : the  file is : Billing_determinant_F7341CDD-BC01-443C-B97B-EDB355D16AD0.xml
# 1968
# 1969 : the  path is : C:\xml_format_file\Feb-bp
# 1969 : the  file is : Billing_determinant_F73EEF6F-D20D-48A8-8904-6000A57AD639.xml
# 1969
# 1970 : the  path is : C:\xml_format_file\Feb-bp
# 1970 : the  file is : Billing_determinant_F78B28F8-2769-43FD-ADEC-F118AB067CC6.xml
# 1970
# 1971 : the  path is : C:\xml_format_file\Feb-bp
# 1971 : the  file is : Billing_determinant_F78D755C-C8A4-4CF2-B3F7-A1BDA9EC5C4E.xml
# 1971
# 1972 : the  path is : C:\xml_format_file\Feb-bp
# 1972 : the  file is : Billing_determinant_F7C5C832-BDC3-4125-BB4C-1246A47F7B1D.xml
# 1972
# 1973 : the  path is : C:\xml_format_file\Feb-bp
# 1973 : the  file is : Billing_determinant_F7CC4835-6DE1-46D1-B78F-53AE38B0239B.xml
# 1973
# 1974 : the  path is : C:\xml_format_file\Feb-bp
# 1974 : the  file is : Billing_determinant_F7CF7988-434C-4152-98D4-5E4FBE72EC9E.xml
# 1974
# 1975 : the  path is : C:\xml_format_file\Feb-bp
# 1975 : the  file is : Billing_determinant_F801B3DC-4A68-4194-925A-7F64DDB498CB.xml
# 1975
# 1976 : the  path is : C:\xml_format_file\Feb-bp
# 1976 : the  file is : Billing_determinant_F80D4FD5-FBF4-4534-AC7C-C8677593C517.xml
# 1976
# 1977 : the  path is : C:\xml_format_file\Feb-bp
# 1977 : the  file is : Billing_determinant_F82CB5D5-B86F-4D8F-B426-D006C5854752.xml
# 1977
# 1978 : the  path is : C:\xml_format_file\Feb-bp
# 1978 : the  file is : Billing_determinant_F854B0B0-22C4-4410-ADA6-4EAD0AFA23F7.xml
# 1978
# 1979 : the  path is : C:\xml_format_file\Feb-bp
# 1979 : the  file is : Billing_determinant_F86378E4-D874-47C9-8EFF-E90A31E72549.xml
# 1979
# 1980 : the  path is : C:\xml_format_file\Feb-bp
# 1980 : the  file is : Billing_determinant_F8AEA426-6ABA-4867-99B5-4DBE0A5A829A.xml
# 1980
# 1981 : the  path is : C:\xml_format_file\Feb-bp
# 1981 : the  file is : Billing_determinant_F8B9E68E-70EC-48C2-86CF-0CBF56048822.xml
# 1981
# 1982 : the  path is : C:\xml_format_file\Feb-bp
# 1982 : the  file is : Billing_determinant_F8D273A2-EE0F-4886-92CA-5B528C8807E8.xml
# 1982
# 1983 : the  path is : C:\xml_format_file\Feb-bp
# 1983 : the  file is : Billing_determinant_F8D7026A-E263-4076-86E0-861F853CE374.xml
# 1983
# 1984 : the  path is : C:\xml_format_file\Feb-bp
# 1984 : the  file is : Billing_determinant_F95B9D43-96AA-4752-83E3-E2B9D34301DE.xml
# 1984
# 1985 : the  path is : C:\xml_format_file\Feb-bp
# 1985 : the  file is : Billing_determinant_F95E4916-8E7E-4773-AC63-0F5BEF6DA136.xml
# 1985
# 1986 : the  path is : C:\xml_format_file\Feb-bp
# 1986 : the  file is : Billing_determinant_F96F11EA-2A50-463A-A0EF-9E6AA35F262D.xml
# 1986
# 1987 : the  path is : C:\xml_format_file\Feb-bp
# 1987 : the  file is : Billing_determinant_F989A401-49EB-40C9-A9FE-77DEB581A788.xml
# 1987
# 1988 : the  path is : C:\xml_format_file\Feb-bp
# 1988 : the  file is : Billing_determinant_F9A018B3-2C4D-487C-B1A5-43318CAC1D8B.xml
# 1988
# 1989 : the  path is : C:\xml_format_file\Feb-bp
# 1989 : the  file is : Billing_determinant_F9A04F77-DB8D-43C1-ADFD-62C3819A24A7.xml
# 1989
# 1990 : the  path is : C:\xml_format_file\Feb-bp
# 1990 : the  file is : Billing_determinant_F9A88FB6-E7E0-4275-AC8E-8B063EE25804.xml
# 1990
# 1991 : the  path is : C:\xml_format_file\Feb-bp
# 1991 : the  file is : Billing_determinant_F9C28F3D-23F7-4EC0-8B87-5341B54D18D9.xml
# 1991
# 1992 : the  path is : C:\xml_format_file\Feb-bp
# 1992 : the  file is : Billing_determinant_FA009A3B-F3D2-47C6-93CC-6CB916E96AEE.xml
# 1992
# 1993 : the  path is : C:\xml_format_file\Feb-bp
# 1993 : the  file is : Billing_determinant_FA02367C-DCC7-4243-A20A-639D3062F133.xml
# 1993
# 1994 : the  path is : C:\xml_format_file\Feb-bp
# 1994 : the  file is : Billing_determinant_FA0698C0-4CC2-45C3-BA0D-51FDDDED32EB.xml
# 1994
# 1995 : the  path is : C:\xml_format_file\Feb-bp
# 1995 : the  file is : Billing_determinant_FA238BC4-7402-4AE6-9C73-3F9CB8EF1427.xml
# 1995
# 1996 : the  path is : C:\xml_format_file\Feb-bp
# 1996 : the  file is : Billing_determinant_FA53A11A-5E39-49D3-8562-9B155643E060.xml
# 1996
# 1997 : the  path is : C:\xml_format_file\Feb-bp
# 1997 : the  file is : Billing_determinant_FA5B10D2-5C5E-4850-9BB6-367711AAB500.xml
# 1997
# 1998 : the  path is : C:\xml_format_file\Feb-bp
# 1998 : the  file is : Billing_determinant_FA65A8A5-FAF6-4AD5-BE7C-A90816632865.xml
# 1998
# 1999 : the  path is : C:\xml_format_file\Feb-bp
# 1999 : the  file is : Billing_determinant_FA689BA8-B787-42A5-B504-A926DA0C238D.xml
# 1999
# 2000 : the  path is : C:\xml_format_file\Feb-bp
# 2000 : the  file is : Billing_determinant_FA82F066-C9C3-4666-956F-3A626CE0410D.xml
# 2000
# 2001 : the  path is : C:\xml_format_file\Feb-bp
# 2001 : the  file is : Billing_determinant_FA9BA9ED-0405-4784-8048-77994800251D.xml
# 2001
# 2002 : the  path is : C:\xml_format_file\Feb-bp
# 2002 : the  file is : Billing_determinant_FACD0345-8131-42DC-ACFC-B192855E36DA.xml
# 2002
# 2003 : the  path is : C:\xml_format_file\Feb-bp
# 2003 : the  file is : Billing_determinant_FADB4C38-0A91-453B-B94D-47615085D0B4.xml
# 2003
# 2004 : the  path is : C:\xml_format_file\Feb-bp
# 2004 : the  file is : Billing_determinant_FB0DB74A-CC61-47A9-9D68-2CFA5CA9BBA5.xml
# 2004
# 2005 : the  path is : C:\xml_format_file\Feb-bp
# 2005 : the  file is : Billing_determinant_FB6AB793-DCB5-4B5A-989C-879460AC5FE7.xml
# 2005
# 2006 : the  path is : C:\xml_format_file\Feb-bp
# 2006 : the  file is : Billing_determinant_FB9D22E5-4E18-4627-B5A4-5DE2D8ADA48C.xml
# 2006
# 2007 : the  path is : C:\xml_format_file\Feb-bp
# 2007 : the  file is : Billing_determinant_FBB48ED4-97FA-4BEE-95B7-14F85559EBC2.xml
# 2007
# 2008 : the  path is : C:\xml_format_file\Feb-bp
# 2008 : the  file is : Billing_determinant_FBDE8697-25F4-44E0-8239-6BB553B10C36.xml
# 2008
# 2009 : the  path is : C:\xml_format_file\Feb-bp
# 2009 : the  file is : Billing_determinant_FBEC3C13-03EF-4137-9C6E-4C4DAD193E1E.xml
# 2009
# 2010 : the  path is : C:\xml_format_file\Feb-bp
# 2010 : the  file is : Billing_determinant_FBEF3CC3-9109-4DF9-A302-EC71EF4444D6.xml
# 2010
# 2011 : the  path is : C:\xml_format_file\Feb-bp
# 2011 : the  file is : Billing_determinant_FBF6FDD7-01E6-45CE-982F-9724C7D1EFD1.xml
# 2011
# 2012 : the  path is : C:\xml_format_file\Feb-bp
# 2012 : the  file is : Billing_determinant_FBFE5339-EFBA-447B-B47B-FA5D26EC925A.xml
# 2012
# 2013 : the  path is : C:\xml_format_file\Feb-bp
# 2013 : the  file is : Billing_determinant_FC2856BA-9E73-4F64-A2BF-3C3E80739D20.xml
# 2013
# 2014 : the  path is : C:\xml_format_file\Feb-bp
# 2014 : the  file is : Billing_determinant_FC421694-F501-4DF5-9CFD-52F341DFF445.xml
# 2014
# 2015 : the  path is : C:\xml_format_file\Feb-bp
# 2015 : the  file is : Billing_determinant_FCBECB10-6F0E-4E9C-8F9C-F968FB69224D.xml
# 2015
# 2016 : the  path is : C:\xml_format_file\Feb-bp
# 2016 : the  file is : Billing_determinant_FCE8DA1D-C6E7-495F-BC54-CD9DADB4A72A.xml
# 2016
# 2017 : the  path is : C:\xml_format_file\Feb-bp
# 2017 : the  file is : Billing_determinant_FCFABCE8-BE30-4A9E-8308-7B7B95E04F61.xml
# 2017
# 2018 : the  path is : C:\xml_format_file\Feb-bp
# 2018 : the  file is : Billing_determinant_FD68FBEE-887A-499A-935F-59CF340D7B99.xml
# 2018
# 2019 : the  path is : C:\xml_format_file\Feb-bp
# 2019 : the  file is : Billing_determinant_FD77B5C8-77F4-4D0F-9EAB-06E6C09A2DC0.xml
# 2019
# 2020 : the  path is : C:\xml_format_file\Feb-bp
# 2020 : the  file is : Billing_determinant_FD9E5308-7C3A-4376-B784-7D42B9D94762.xml
# 2020
# 2021 : the  path is : C:\xml_format_file\Feb-bp
# 2021 : the  file is : Billing_determinant_FDB2822D-70A2-48BD-BC21-D4D818FBE1EF.xml
# 2021
# 2022 : the  path is : C:\xml_format_file\Feb-bp
# 2022 : the  file is : Billing_determinant_FE36BEBA-9590-4F99-A06E-E157EB2B30B7.xml
# 2022
# 2023 : the  path is : C:\xml_format_file\Feb-bp
# 2023 : the  file is : Billing_determinant_FE4B310C-13C3-45F6-8040-A8B665280988.xml
# 2023
# 2024 : the  path is : C:\xml_format_file\Feb-bp
# 2024 : the  file is : Billing_determinant_FE772A21-7601-40A6-858A-830F02963CFE.xml
# 2024
# 2025 : the  path is : C:\xml_format_file\Feb-bp
# 2025 : the  file is : Billing_determinant_FEA507B1-3CEE-4A51-A3B3-78A7675A303A.xml
# 2025
# 2026 : the  path is : C:\xml_format_file\Feb-bp
# 2026 : the  file is : Billing_determinant_FEB112DA-4C88-4617-B223-C7AF32B010E2.xml
# 2026
# 2027 : the  path is : C:\xml_format_file\Feb-bp
# 2027 : the  file is : Billing_determinant_FEF46482-7CD5-4A72-8AEC-DE2ACD2D9046.xml
# 2027
# 2028 : the  path is : C:\xml_format_file\Feb-bp
# 2028 : the  file is : Billing_determinant_FEFD1E59-8127-4E4B-8104-BA03557EE5C5.xml
# 2028
# 2029 : the  path is : C:\xml_format_file\Feb-bp
# 2029 : the  file is : Billing_determinant_FF12628C-4B94-4DD3-BE05-C3D1E8D21476.xml
# 2029
# 2030 : the  path is : C:\xml_format_file\Feb-bp
# 2030 : the  file is : Billing_determinant_FF238F32-08A1-4E9E-9CFB-F004D5BA12C1.xml
# 2030
# 2031 : the  path is : C:\xml_format_file\Feb-bp
# 2031 : the  file is : Billing_determinant_FF668B2C-5D48-4238-B2C0-C03E1BF687C1.xml
# 2031
# 2032 : the  path is : C:\xml_format_file\Feb-bp
# 2032 : the  file is : Billing_determinant_FF918778-7764-4A4F-AB2D-82781371D173.xml
# 2032
# 2033 : the  path is : C:\xml_format_file\Feb-bp
# 2033 : the  file is : Billing_determinant_FFBF0AA7-53F3-4A22-B67D-FB9ABADF3A36.xml
# 2033
# 2034 : the  path is : C:\xml_format_file\Feb-bp
# 2034 : the  file is : Billing_determinant_FFD35953-F869-4327-B02B-A20A9631A2DF.xml
# 2034

# %%
df_mdm.drop_duplicates(subset=['mdm_xml_file_name'],ignore_index=True,inplace=True)

# %%
df_mdm.to_csv(r'C:\Users\Ratan Kumar Jha\Desktop\CHECK DATA NEW\df_mdm.csv')

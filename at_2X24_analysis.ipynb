# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\Ratan Kumar Jha\Desktop\attendence_analysis\new_att_2x24_P_A_Data_new.xlsx")

# %%
df.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\attendence_analysis\att_2024_2023_M_D_ATT_P_DATA.csv",index=False)

# %%
att_2024_2023_M_D_ATT_P_DATA=pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\attendence_analysis\att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK.csv")

# %%
att_2024_2023_M_D_ATT_P_DATA.head()
# Out:
#          date        DAY Eric LEHOUELLEUR Babita Thakur Mohit Jain  \
# 0  01-07-2023   Saturday          holiday       holiday    holiday
# 1  02-07-2023     Sunday          holiday       holiday    holiday
# 2  03-07-2023     Monday          present       present        WFH
# 3  04-07-2023    Tuesday            PATNA       present        WFH
# 4  05-07-2023  Wednesday          present       present    present
#
#          Narendra Prasad Mohanty  Argha Basu Mukul Miglani Aashish Sharma  \
# 0                         holiday        NaN       holiday        holiday
# 1                         holiday        NaN       holiday        holiday
# 2  Not Present with approval/info        NaN           WFH        present
# 3  Not Present with approval/info        NaN           WFH        present
# 4                             WFH        NaN       present        present
#
#   Anand Shimar  ... Satyam Kumar Praveen Kumar Saurabh Sharma  \
# ...

# %%
att_2024_2023_M_D_ATT_P_DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      184 non-null    object
#  1   DAY                       184 non-null    object
#  2   Eric LEHOUELLEUR          184 non-null    object
#  3   Babita Thakur             184 non-null    object
#  4   Mohit Jain                184 non-null    object
#  5   Narendra Prasad Mohanty   184 non-null    object
#  6   Argha Basu                21 non-null     object
#  7   Mukul Miglani             184 non-null    object
#  8   Aashish Sharma            184 non-null    object
#  9   Anand Shimar              184 non-null    object
#  10  Rajiv Aggarwal            149 non-null    object
#  11  Vikas Kumar Sharma        184 non-null    object
#  12  Digvijay                  184 non-null    object
# ...

# %%
#att_2024_2023_M_D_ATT_P_DATA['date'] = pd.to_datetime(att_2024_2023_M_D_ATT_P_DATA['date'])
att_2024_2023_M_D_ATT_P_DATA['date']  = att_2024_2023_M_D_ATT_P_DATA['date'] .astype('str')

# %%
from datetime import datetime
import pandas as pd

# Assuming 'date' column is in the format "%d-%m-%Y"
att_2024_2023_M_D_ATT_P_DATA['date'] = pd.to_datetime(att_2024_2023_M_D_ATT_P_DATA['date'], format="%d-%m-%Y")

# %%
att_2024_2023_M_D_ATT_P_DATA.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\attendence_analysis\att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK.csv",index=False)

# %%
att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK=att_2024_2023_M_D_ATT_P_DATA.replace('OFFICE NOT JOINED',np.nan)

# %%
att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK.head()
# Out:
#         date        DAY Eric LEHOUELLEUR Babita Thakur    Mohit Jain  \
# 0 2023-07-01   Saturday          holiday       holiday       holiday
# 1 2023-07-02     Sunday          holiday       holiday       holiday
# 2 2023-07-03     Monday          present       present  WFH or LEAVE
# 3 2023-07-04    Tuesday            PATNA       present  WFH or LEAVE
# 4 2023-07-05  Wednesday          present       present       present
#
#          Narendra Prasad Mohanty  Argha Basu Mukul Miglani Aashish Sharma  \
# 0                         holiday        NaN       holiday        holiday
# 1                         holiday        NaN       holiday        holiday
# 2  Not Present with approval/info        NaN  WFH or LEAVE        present
# 3  Not Present with approval/info        NaN  WFH or LEAVE        present
# 4                    WFH or LEAVE        NaN       present        present
#
#   Anand Shimar  ... Satyam Kumar Praveen Kumar Saurabh Sharma  \
# ...

# %%
att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\attendence_analysis\att_2024_2023_M_D_ATT_P_DATA_NEW_CHECK.csv",index=False)
